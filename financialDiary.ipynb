# %% [markdown]
# <a href="https://colab.research.google.com/github/Aromie/exercise/blob/master/doitPyDA83p.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

financialDiary = [['income1',80,'11-01'],['income2',30,'11-06'],['samca',-83,'11-06'],['socks',-2.4,'11-07']]
fD=pd.DataFrame(financialDiary, columns=['category','amount','date'])
#df = pd.DataFrame(data, columns=['name', 'English', 'math'])
fD
# Out:
#   category  amount   date
# 0  income1    80.0  11-01
# 1  income2    30.0  11-06
# 2    samca   -83.0  11-06
# 3    socks    -2.4  11-07

# %%
# Calculate the balance based on the "amount" column
fD['balance'] = fD['amount'].cumsum()
fD
# Out:
#   category  amount   date  balance
# 0  income1    80.0  11-01     80.0
# 1  income2    30.0  11-06    110.0
# 2    samca   -83.0  11-06     27.0
# 3    socks    -2.4  11-07     24.6
